# %% [markdown]
# # File1
#
# # "THE PRICE IS RIGHT" Capstone Project
#
# This Folder - fine tune an open-source model!
#
# A model that can estimate how much something costs, from its description.
#
# # Order of play
#
# File 1: QLoRA
# File 2: Prompt Data and Base Model
# File 3: Train
# File 4: Eval

# %% [markdown]
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1IUJ84lIsVXPJO2oLLa7_tQHcTqhtU5wl?usp=sharing
