# %% [markdown]
# # The Price is Right
#
# ## Part C Order of Play
#
# File 1: Modal.com and SpecialistAgent
# File 2: RAG, FrontierAgent, Ensemble Agent
# File 3: ScannerAgent, MessengerAgent
# File 4: AutonomousPlannerAgent and DealAgentFramework
# File 5: The Price Is Right Finale
#
#
# In this file we'll build another piece of the puzzle: a ScanningAgent that looks for promising deals by subscribing to RSS feeds.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from agents.deals import ScrapedDeal, DealSelection
import logging
import requests
load_dotenv(override=True)
openai = OpenAI()
MODEL = 'gpt-5-mini'

# %%
deals = ScrapedDeal.fetch(show_progress=True)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:58<00:00, 19.40s/it]

# %%
len(deals)
# Out:
# 30

# %%
deals[10].describe()
# Out:
# 'Title: Refurb Apple 7th-Gen. iPad 10.2" 128GB WiFi Tablet (2019) for $99 + free shipping\nDetails: It\'s the best deal we\'ve seen for this model. It includes a 1-year Allstate warranty. Buy Now at eBay\nFeatures: \nURL: https://www.dealnews.com/products/Apple/Apple-7-th-Gen-iPad-10-2-128-GB-Wi-Fi-Tablet-2019/69733.html?iref=rss-c39'

# %% [markdown]
# ### We are going to ask GPT-5-mini to summarize deals and identify their price

# %%
SYSTEM_PROMPT = """You identify and summarize the 5 most detailed deals from a list, by selecting deals that have the most detailed, high quality description and the most clear price.
Respond strictly in JSON with no explanation, using this format. You should provide the price as a number derived from the description. If the price of a deal isn't clear, do not include that deal in your response.
Most important is that you respond with the 5 deals that have the most detailed product description with price. It's not important to mention the terms of the deal; most important is a thorough description of the product.
Be careful with products that are described as "$XXX off" or "reduced by $XXX" - this isn't the actual price of the product. Only respond with products when you are highly confident about the price. 
"""

USER_PROMPT_PREFIX = """Respond with the most promising 5 deals from this list, selecting those which have the most detailed, high quality product description and a clear price that is greater than 0.
You should rephrase the description to be a summary of the product itself, not the terms of the deal.
Remember to respond with a short paragraph of text in the product_description field for each of the 5 items that you select.
Be careful with products that are described as "$XXX off" or "reduced by $XXX" - this isn't the actual price of the product. Only respond with products when you are highly confident about the price. 

Deals:

"""

USER_PROMPT_SUFFIX = "\n\nInclude exactly 5 deals, no more."

# %%
# this makes a suitable user prompt given scraped deals

def make_user_prompt(scraped):
    user_prompt = USER_PROMPT_PREFIX
    user_prompt += '\n\n'.join([scrape.describe() for scrape in scraped])
    user_prompt += USER_PROMPT_SUFFIX
    return user_prompt

# %%
# Let's create a user prompt for the deals we just scraped, and look at how it begins

user_prompt = make_user_prompt(deals)
print(user_prompt[:2000])
messages = [{"role": "system", "content": SYSTEM_PROMPT}, {"role": "user", "content": user_prompt}]
# Out:
# Respond with the most promising 5 deals from this list, selecting those which have the most detailed, high quality product description and a clear price that is greater than 0.
# You should rephrase the description to be a summary of the product itself, not the terms of the deal.
# Remember to respond with a short paragraph of text in the product_description field for each of the 5 items that you select.
# Be careful with products that are described as "$XXX off" or "reduced by $XXX" - this isn't the actual price of the product. Only respond with products when you are highly confident about the price.
#
# Deals:
#
# Title: Open-box Apple AirTag for $19 + free shipping
# Details: That's within a buck of the lowest price we've seen. Buy Now at Amazon
# Features:
# URL: https://www.dealnews.com/products/Apple/Apple-Air-Tag/347630.html?iref=rss-c142
#
# Title: Toshiba M550 Series 55M550NU 55" QLED 4K UHD Fire TV for $200 + free shipping
# Details: Looking for a cheap TV? This one is $200 off and a great price for 55". Buy Now at Best Buy
# Features: 4K resolution Dolby Vision, HDR 10, HDR 10+, HLG works w/ Amazon Alexa, Apple HomeKit 4 HDMI inputs Model: 55M550NU
# URL: https://www.dealnews.com/products/Toshiba/Toshiba-M550-Series-55-M550-NU-55-QLED-4-K-UHD-Fire-TV/489273.html?iref=rss-c142
#
# Title: Kospet Tank T4C Smartwatch for $130 + free shipping
# Details: Apply coupon code "DNTANK" for a savings of $30. Buy Now at Kospet
# Features: Built-in Walkie-Talkie with 40m range Integrated 5-level pro flashlight Up to 15 days of battery life MIL-STD-810H military-grade durability 1.5" AMOLED high-brightness round display IP69K & 5 ATM water resistance Dual-band six-system GNSS tracking
# URL: https://www.dealnews.com/Kospet-Tank-T4-C-Smartwatch-for-130-free-shipping/21806634.html?iref=rss-c142
#
# Title: Open-box Unlocked Motorola Moto G Power 5G 128GB Phone (2024) for $81 + free shipping
# Details: Use promo code "VIPOUTLET2026" to drop this model to the best price we've seen. Buy Now at eBay
# Features:
# URL:

# %%
response = openai.chat.completions.parse(model=MODEL, messages=messages, response_format=DealSelection, reasoning_effort="minimal")
results = response.choices[0].message.parsed
results
# Out:
# DealSelection(deals=[Deal(product_description="Apple AirTag (open-box) — A small, coin-shaped Bluetooth tracking device designed to help you locate items like keys, bags, and other personal belongings through Apple's Find My network. It features precision finding with Ultra Wideband on supported iPhones, replaceable CR2032 battery offering about a year of life, and a water- and dust-resistant design. The open-box unit is functionally identical to new AirTags and pairs quickly with iOS devices for location, sound alerts, and separation notifications.", price=19.0, url='https://www.dealnews.com/products/Apple/Apple-Air-Tag/347630.html?iref=rss-c142'), Deal(product_description='Toshiba M550 Series 55" 4K QLED Fire TV (Model 55M550NU) — A 55-inch QLED 4K UHD television with Dolby Vision, HDR10, HDR10+ and HLG support for enhanced contrast and color. It runs Amazon Fire TV OS for built-in streaming apps and voice control, has four HDMI inputs for multiple sources, and works with Amazon Alexa and Apple HomeKit for smart-home integration. The set targets good picture performance and smart features at an entry-level price point.', price=200.0, url='https://www.dealnews.com/products/Toshiba/Toshiba-M550-Series-55-M550-NU-55-QLED-4-K-UHD-Fire-TV/489273.html?iref=rss-c142'), Deal(product_description='Kospet Tank T4C Smartwatch — A rugged outdoor-focused smartwatch with a 1.5" high-brightness AMOLED round display, military-grade MIL-STD-810H durability, IP69K and 5 ATM water resistance, and up to 15 days of battery life. It includes built-in walkie-talkie capability (40m range), dual-band six-system GNSS for improved location tracking, and a 5-level professional flashlight for outdoor use. The device is built for durability and extended outdoor tracking and communication.', price=130.0, url='https://www.dealnews.com/Kospet-Tank-T4-C-Smartwatch-for-130-free-shipping/21806634.html?iref=rss-c142'), Deal(product_description='Eco-Worthy 48V 314Ah LiFePO4 Vertical Standing Backup Battery — A large-capacity, 48-volt LiFePO4 deep-cycle battery intended for backup power and off-grid energy storage. It features a 200A PACE BMS for battery management, more than 80% depth-of-discharge retention after 10,000 cycles, detachable terminals for flexible installation and expansion, and a built-in display for monitoring state-of-charge and system parameters. The unit is designed for long cycle life and high-capacity energy storage applications.', price=1649.99, url='https://www.dealnews.com/Eco-Worthy-48-V-314-AH-Li-Fe-PO4-Vertical-Standing-Backup-Battery-for-1-650-free-shipping/21806291.html?iref=rss-c142'), Deal(product_description='MOVA Z60 Ultra Roller Complete Robot Vacuum — A high-end robot vacuum and mop with extreme suction (28,000 Pa) and an integrated roller mop system that self-cleans for streak-free floors. It includes AutoShield carpet protection that deploys a moisture-blocking shield, the ability to climb thresholds up to 8 cm, and claims near-complete coverage via extendable roller mop and side brush reach. The Z60 targets thorough cleaning performance for large or challenging floorplans.', price=999.0, url='https://www.dealnews.com/products/Mova/MOVA-Z60-Ultra-Roller-Complete-Robot-Vacuum/495937.html?iref=rss-f1912')])

# %%
for deal in results.deals:
    print(deal.product_description)
    print(deal.price)
    print(deal.url)
    print()
# Out:
# Apple AirTag (open-box) — A small, coin-shaped Bluetooth tracking device designed to help you locate items like keys, bags, and other personal belongings through Apple's Find My network. It features precision finding with Ultra Wideband on supported iPhones, replaceable CR2032 battery offering about a year of life, and a water- and dust-resistant design. The open-box unit is functionally identical to new AirTags and pairs quickly with iOS devices for location, sound alerts, and separation notifications.
# 19.0
# https://www.dealnews.com/products/Apple/Apple-Air-Tag/347630.html?iref=rss-c142
#
# Toshiba M550 Series 55" 4K QLED Fire TV (Model 55M550NU) — A 55-inch QLED 4K UHD television with Dolby Vision, HDR10, HDR10+ and HLG support for enhanced contrast and color. It runs Amazon Fire TV OS for built-in streaming apps and voice control, has four HDMI inputs for multiple sources, and works with Amazon Alexa and Apple HomeKit for smart-home integration. The set targets good picture performance and smart features at an entry-level price point.
# 200.0
# https://www.dealnews.com/products/Toshiba/Toshiba-M550-Series-55-M550-NU-55-QLED-4-K-UHD-Fire-TV/489273.html?iref=rss-c142
#
# Kospet Tank T4C Smartwatch — A rugged outdoor-focused smartwatch with a 1.5" high-brightness AMOLED round display, military-grade MIL-STD-810H durability, IP69K and 5 ATM water resistance, and up to 15 days of battery life. It includes built-in walkie-talkie capability (40m range), dual-band six-system GNSS for improved location tracking, and a 5-level professional flashlight for outdoor use. The device is built for durability and extended outdoor tracking and communication.
# 130.0
# https://www.dealnews.com/Kospet-Tank-T4-C-Smartwatch-for-130-free-shipping/21806634.html?iref=rss-c142
#
# Eco-Worthy 48V 314Ah LiFePO4 Vertical Standing Backup Battery — A large-capacity, 48-volt LiFePO4 deep-cycle battery intended for backup power and off-grid energy storage. It features a 200A PACE BMS for battery management, more than 80% depth-of-discharge retention after 10,000 cycles, detachable terminals for flexible installation and expansion, and a built-in display for monitoring state-of-charge and system parameters. The unit is designed for long cycle life and high-capacity energy storage applications.
# 1649.99
# https://www.dealnews.com/Eco-Worthy-48-V-314-AH-Li-Fe-PO4-Vertical-Standing-Backup-Battery-for-1-650-free-shipping/21806291.html?iref=rss-c142
#
# MOVA Z60 Ultra Roller Complete Robot Vacuum — A high-end robot vacuum and mop with extreme suction (28,000 Pa) and an integrated roller mop system that self-cleans for streak-free floors. It includes AutoShield carpet protection that deploys a moisture-blocking shield, the ability to climb thresholds up to 8 cm, and claims near-complete coverage via extendable roller mop and side brush reach. The Z60 targets thorough cleaning performance for large or challenging floorplans.
# 999.0
# https://www.dealnews.com/products/Mova/MOVA-Z60-Ultra-Roller-Complete-Robot-Vacuum/495937.html?iref=rss-f1912

# %%
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
from agents.scanner_agent import ScannerAgent

# %%
agent = ScannerAgent()
result = agent.scan()
# Out:
# INFO:root:[Scanner Agent] Scanner Agent is initializing
# INFO:root:[Scanner Agent] Scanner Agent is ready
# INFO:root:[Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# INFO:root:[Scanner Agent] Scanner Agent received 30 deals not already scraped
# INFO:root:[Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI

# %%
result
# Out:
# DealSelection(deals=[Deal(product_description="Apple AirTag (open-box) — a small, coin-shaped Bluetooth tracker designed to help you locate keys, bags, and other items using Apple's Find My network. It pairs with iPhone/iPad to display precise locations, offers a replaceable battery that lasts about a year, and supports Precision Finding on compatible iPhones. The open-box unit is the same physical AirTag hardware (stainless steel, speaker for sound alerts) but sold in an open-box condition.", price=19.0, url='https://www.dealnews.com/products/Apple/Apple-Air-Tag/347630.html?iref=rss-c142'), Deal(product_description='Apple Mac mini (M4, 2024) — compact desktop powered by Apple’s M4 chip with Apple Intelligence, configured with 16GB of unified RAM and a 256GB SSD. It runs macOS and is suitable for productivity, media, and light creative workflows in a small-footprint aluminum enclosure with multiple I/O ports for displays and peripherals. This listing is the new Mac mini model (MU9D3LL/A) at a reduced price.', price=400.0, url='https://www.dealnews.com/products/Apple/Apple-Mac-mini-M4-Desktop-2024-w-256-GB-SSD/484139.html?iref=rss-c39'), Deal(product_description="Eco-Worthy 48V 314Ah LiFePO4 Vertical Standing Backup Battery — a high-capacity lithium iron phosphate battery for off-grid and backup power systems, rated 48V and 314Ah with a 200A PACE BMS for protection. The pack offers >80% depth of discharge after 10,000 cycles, detachable terminals for flexible installation and expansion, and a built-in display for real-time monitoring. It's designed for long cycle life and heavy-duty energy storage use.", price=1649.99, url='https://www.dealnews.com/Eco-Worthy-48-V-314-AH-Li-Fe-PO4-Vertical-Standing-Backup-Battery-for-1-650-free-shipping/21806291.html?iref=rss-c142'), Deal(product_description='Apple Mac mini (M4, 2024) — open-box configuration of the M4 Mac mini with 16GB RAM and a 256GB SSD, offering the same compact aluminum chassis and macOS experience as new units. Powered by Apple’s M4 chip and suited for desktop tasks, media playback, and light content creation, this open-box unit provides the higher-performance M4 platform at a reduced price point.', price=487.0, url='https://www.dealnews.com/products/Apple/Apple-Mac-mini-M4-Desktop-2024-w-256-GB-SSD/484139.html?iref=rss-c39'), Deal(product_description='MOVA V50 Ultra Complete Robot Vacuum — a high-performance autonomous floor-care robot with up to 24,000Pa suction and an auto-detaching mop system. It includes self-cleaning and HEPA filtration, a rapid 1-hour mop drying feature, and the ability to cross barriers up to 6 cm. Designed as an all-in-one solution for vacuuming, mopping, and self-maintenance in larger homes.', price=799.0, url='https://www.dealnews.com/products/Mova/MOVA-V50-Ultra-Complete-Robot-Vacuum/496017.html?iref=rss-f1912')])

# %% [markdown]
# ### Introducing Pushover
#
# Pushover is a nifty tool for sending Push Notifications to your phone.
#
# It's super easy to set up and install!
#
# Simply visit https://pushover.net/ and click 'Login or Signup' on the top right to sign up for a free account, and create your API keys.
#
# Once you've signed up, on the home screen, click "Create an Application/API Token", and give it any name (like AIEngineer) and click Create Application.
#
# Then add 2 lines to your `.env` file:
#
# PUSHOVER_USER=_put the key that's on the top right of your Pushover home screen and probably starts with a u_
# PUSHOVER_TOKEN=_put the key when you click into your new application called Agents (or whatever) and probably starts with an a_
#
# Remember to save your `.env` file, and run `load_dotenv(override=True)` after saving, to set your environment variables.
#
# Finally, click "Add Phone, Tablet or Desktop" to install on your phone.

# %%
load_dotenv(override=True)
# Out:
# True

# %%
pushover_user = os.getenv('PUSHOVER_USER')
pushover_token = os.getenv('PUSHOVER_TOKEN')
pushover_url = "https://api.pushover.net/1/messages.json"

# %%
if pushover_user:
    print(f"Pushover user found and starts with {pushover_user[0]}")
else:
    print("Pushover user not found")

if pushover_token:
    print(f"Pushover token found and starts with {pushover_token[0]}")
else:
    print("Pushover token not found")
# Out:
# Pushover user found and starts with u
# Pushover token found and starts with a

# %%
def push(message):
    print(f"Push: {message}")
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, data=payload)

# %%
push("MASSIVE DEAL!!")
# Out:
# Push: MASSIVE DEAL!!

# %%
from agents.messaging_agent import MessagingAgent

agent = MessagingAgent()
agent.push("SUCH A MASSIVE DEAL!!")
# Out:
# INFO:root:[Messaging Agent] Messaging Agent is initializing
# INFO:root:[Messaging Agent] Messaging Agent has initialized Pushover and Claude
# INFO:root:[Messaging Agent] Messaging Agent is sending a push notification

# %%
agent.notify("A special deal on Sumsung 60 inch LED TV going at a great bargain", 300, 1000, "www.samsung.com")
# Out:
# INFO:root:[Messaging Agent] Messaging Agent is using Claude to craft the message
# 14:44:05 - LiteLLM:INFO: utils.py:3443 -
# LiteLLM completion() model= anthropic/claude-sonnet-4; provider = openrouter
# INFO:LiteLLM:
# LiteLLM completion() model= anthropic/claude-sonnet-4; provider = openrouter
# 14:44:08 - LiteLLM:INFO: utils.py:1311 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# INFO:root:[Messaging Agent] Messaging Agent is sending a push notification
# INFO:root:[Messaging Agent] Messaging Agent has completed
