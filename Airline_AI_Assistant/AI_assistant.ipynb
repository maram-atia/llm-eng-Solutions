# %%
# imports

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
import sqlite3
DB = "prices.db"

# %%
def get_ticket_price(city):
    print(f"DATABASE TOOL CALLED: Getting price for {city}", flush=True)
    with sqlite3.connect(DB) as conn:
        cursor = conn.cursor()
        cursor.execute('SELECT price FROM prices WHERE city = ?', (city.lower(),))
        result = cursor.fetchone()
        return f"Ticket price to {city} is ${result[0]}" if result else "No price data available for this city"

# %%
get_ticket_price("Paris")
# Out:
# DATABASE TOOL CALLED: Getting price for Paris
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ticket_price("Paris")
#
# Cell In[5], line 5, in get_ticket_price(city)
#       3 with sqlite3.connect(DB) as conn:
#       4     cursor = conn.cursor()
# ----> 5     cursor.execute('SELECT price FROM prices WHERE city = ?', (city.lower(),))
#       6     result = cursor.fetchone()
#       7     return f"Ticket price to {city} is ${result[0]}" if result else "No price data available for this city"
#
# OperationalError: no such table: prices
